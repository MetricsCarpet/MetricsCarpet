# %%
import os
from sh import git


def checkout_version(version):
    root_path = os.getcwd()
    os.chdir('%s/zurich_corpus/Infectio' % root_path)
    
    res = git.checkout(version)
    assert res.exit_code == 0
    
    os.chdir(root_path)
    
# checkout_version('0.2')

# %%
from mcarpet.corpus import SoftwareProduct
from mcarpet.toolset import MatlabTool
from mcarpet.experiments import Experiment, MeasurementAggregator
from zurich_corpus import ZurichCorpus


def get_measurements(product, expertiment_name):    
    
    experiment = Experiment(expertiment_name)
    tool = MatlabTool()
    tool.attach_to_experiment(experiment)    
    print 'This might take some time, since it starts MATLAB'
    # TODO: checkout other versions
    tool.measure(product)
    
    
def measure_infectio_versions():
    versions = ['0.1', '0.2', '0.3']
    product = ZurichCorpus().get_product('Infectio')
    
    for version in versions:
        print version
        checkout_version(version)
        get_measurements(product, 'Infectio_v%s' % version)

def measure_cp1():
    product = ZurichCorpus().get_product('CellProfiler1.0')
    get_measurements(product, expertiment_name='CellProfiler_v1.0')

# %%
#measure_infectio_versions()
measure_cp1()
# Out:
# ERROR:mcarpet.utils:-STDERR---------------------------------------------------------------------------------
# Picked up JAVA_TOOL_OPTIONS: -javaagent:/usr/share/java/jayatanaag.jar
# This might take some time, since it starts MATLAB
# 2015-05-31 23:25:29,269 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2015-05-31 23:25:29,276 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2015-05-31 23:25:29,285 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2015-05-31 23:25:29,290 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2015-05-31 23:25:29,302 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("measurements")
# INFO:sqlalchemy.engine.base.Engine:PRAGMA table_info("measurements")
# 2015-05-31 23:25:29,308 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2015-05-31 23:25:29,332 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE measurements (
# 	"index" BIGINT,
# 	line_counts BIGINT,
# 	comments BIGINT,
# 	cyclomatic_complexity BIGINT,
# 	help_metric BIGINT,
# 	filename TEXT,
# 	pathname TEXT
# )
# INFO:sqlalchemy.engine.base.Engine:
# CREATE TABLE measurements (
# 	"index" BIGINT,
# 	line_counts BIGINT,
# 	comments BIGINT,
# 	cyclomatic_complexity BIGINT,
# 	help_metric BIGINT,
# 	filename TEXT,
# 	pathname TEXT
# )
# 2015-05-31 23:25:29,338 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2015-05-31 23:25:29,524 INFO sqlalchemy.engine.base.Engine COMMIT
# INFO:sqlalchemy.engine.base.Engine:COMMIT
# 2015-05-31 23:25:29,532 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_measurements_index ON measurements ("index")
# INFO:sqlalchemy.engine.base.Engine:CREATE INDEX ix_measurements_index ON measurements ("index")
# 2015-05-31 23:25:29,539 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2015-05-31 23:25:29,703 INFO sqlalchemy.engine.base.Engine COMMIT
# INFO:sqlalchemy.engine.base.Engine:COMMIT
# 2015-05-31 23:25:29,719 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.base.Engine:BEGIN (implicit)
# 2015-05-31 23:25:29,809 INFO sqlalchemy.engine.base.Engine INSERT INTO measurements ("index", line_counts, comments, cyclomatic_complexity, help_metric, filename, pathname) VALUES (?, ?, ?, ?, ?, ?, ?)
# INFO:sqlalchemy.engine.base.Engine:INSERT INTO measurements ("index", line_counts, comments, cyclomatic_complexity, help_metric, filename, pathname) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2015-05-31 23:25:29,816 INFO sqlalchemy.engine.base.Engine ((0, 228, 99, 26, 1, u'BuildCellProfiler.m', u'BuildCellProfiler.m'), (1, 100, 19, 11, 1, u'CPCluster.m', u'CPCluster.m'), (2, 4605, 1104, 91, 1, u'CellProfiler.m', u'CellProfiler.m'), (3, 311, 38, 41, 1, u'CompileWizard.m', u'CompileWizard.m'), (4, 5, 2, 0, 3, u'CPCluster_mcr/CPCluster/CPCluster.m', u'CPCluster_mcr/CPCluster/CPCluster.m'), (5, 8, 5, 0, 3, u'CPCluster_mcr/CPsubfunctions/CPShowPlateMapDataFig.m', u'CPCluster_mcr/CPsubfunctions/CPShowPlateMapDataFig.m'), (6, 5, 3, 0, 3, u'CPCluster_mcr/CPsubfunctions/CPShowPlateMapDataGUI.m', u'CPCluster_mcr/CPsubfunctions/CPShowPlateMapDataGUI.m'), (7, 3, 1, 0, 3, u'CPCluster_mcr/CPsubfunctions/CP_ImagePopupmenu_Callback.m', u'CPCluster_mcr/CPsubfunctions/CP_ImagePopupmenu_Callback.m')  ... displaying 10 of 758 total bound parameter sets ...  (756, 396, 178, 38, 1, u'Modules/Tile.m', u'Modules/Tile.m'), (757, 649, 342, 33, 1, u'Modules/TrackObjects.m', u'Modules/TrackObjects.m'))
# INFO:sqlalchemy.engine.base.Engine:((0, 228, 99, 26, 1, u'BuildCellProfiler.m', u'BuildCellProfiler.m'), (1, 100, 19, 11, 1, u'CPCluster.m', u'CPCluster.m'), (2, 4605, 1104, 91, 1, u'CellProfiler.m', u'CellProfiler.m'), (3, 311, 38, 41, 1, u'CompileWizard.m', u'CompileWizard.m'), (4, 5, 2, 0, 3, u'CPCluster_mcr/CPCluster/CPCluster.m', u'CPCluster_mcr/CPCluster/CPCluster.m'), (5, 8, 5, 0, 3, u'CPCluster_mcr/CPsubfunctions/CPShowPlateMapDataFig.m', u'CPCluster_mcr/CPsubfunctions/CPShowPlateMapDataFig.m'), (6, 5, 3, 0, 3, u'CPCluster_mcr/CPsubfunctions/CPShowPlateMapDataGUI.m', u'CPCluster_mcr/CPsubfunctions/CPShowPlateMapDataGUI.m'), (7, 3, 1, 0, 3, u'CPCluster_mcr/CPsubfunctions/CP_ImagePopupmenu_Callback.m', u'CPCluster_mcr/CPsubfunctions/CP_ImagePopupmenu_Callback.m')  ... displaying 10 of 758 total bound parameter sets ...  (756, 396, 178, 38, 1, u'Modules/Tile.m', u'Modules/Tile.m'), (757, 649, 342, 33, 1, u'Modules/TrackObjects.m', u'Modules/TrackObjects.m'))
# 2015-05-31 23:25:29,872 INFO sqlalchemy.engine.base.Engine COMMIT
# INFO:sqlalchemy.engine.base.Engine:COMMIT
# 2015-05-31 23:25:30,072 INFO sqlalchemy.engine.base.Engine SELECT name FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE type='table' ORDER BY name
# INFO:sqlalchemy.engine.base.Engine:SELECT name FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE type='table' ORDER BY name
# 2015-05-31 23:25:30,078 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
import sqlite3
import pandas as pd

def load_measurements(experiments):
    data = {}
    for experiment in experiments:
        name = experiment['name']
        filename = experiment['file']
        con = sqlite3.connect("var/measurements/%s" % experiment['file'])
        data[name] = pd.read_sql("SELECT * from measurements", con).drop('index', axis=1)    
    return data

# %%
infectio_experiments = [
    {
        'name': 'Infectio_v0.1',
        'file': 'Infectio_v0.1_150515003418.sqlite',
    },
    {
        'name': 'Infectio_v0.2',
        'file': 'Infectio_v0.2_150515003418.sqlite',
    },
    {
        'name': 'Infectio_v0.3',
        'file': 'Infectio_v0.3_150515003418.sqlite',
    },
]
    
cp_experiments = [   
    {
        'name': 'CellProfiler_v1.0',
        'file': 'CellProfiler_v1.0_150531230704.sqlite',
    },
]


data = {}
data['infectio'] = load_measurements(infectio_experiments)
data['cp'] = load_measurements(cp_experiments)

# %%
class MinMaxNorm(object):
    
    def __init__(self):
        self.min = 0
        self.max = 0
        self.metric_labels = ['line_counts', 'comments', 'cyclomatic_complexity', 'help_metric']

    def find_minmax(self, data):
        self.min = min([self.min, data.min()])
        self.max = max([self.max, data.max()])
        
    def normalize_minmax(self, data):
        data_norm = (data - self.min) / (self.max - self.min)
        return data_norm

    def norm_metrics(self, data):
        result = {}
        for name in data:
            result[name] = data[name].copy()
            for metric in metric_labels:
                result[name][metric] = normalize_minmax(result[name][metric])
        return result

    def merge_metrics(self, data):
        for name in data:
            norm_df = data[name].copy().sort('filename').filter(metric_labels, axis=1)
            for metric in metric_labels:
                norm_df[metric] = normalize_minmax(norm_df[metric])

# print data.keys()
                
# Share min-max per column (key)
norm_data = {}
for key in normalizer.metric_labels:
    normalizer = MinMaxNorm()
    for product in data:
        for version in data[product]:
            normalizer.find_minmax(data[product][version][key])
    for product in data:
        if product not in norm_data:
            norm_data[product] = {}
        for version in data[product]:
            if version not in norm_data[product]:
                norm_data[product][version] = data[product][version].copy()
            norm_data[product][version][key] = normalizer.normalize_minmax(norm_data[product][version][key])

# Merge infectio
infectio_mdata = None
for version in norm_data['infectio']:
    dash = version.replace('Infectio_', '')
    norm_data['infectio'][version] = norm_data['infectio'][version].drop('pathname', axis=1)
    names = dict((n, n + '_' + dash) for n in norm_data['infectio'][version].columns if n != 'filename')
    norm_data['infectio'][version].rename(columns=names, inplace=True)
    if infectio_mdata is None:
        infectio_mdata = norm_data['infectio'][version]
    else:
        infectio_mdata = infectio_mdata.merge(norm_data['infectio'][version], on='filename', how='outer')
# infectio_mdata = norm_data['infectio']['Infectio_v0.1'].merge(norm_data['infectio']['Infectio_v0.2'], on='filename', how='outer').merge(norm_data['infectio']['Infectio_v0.3'], on='filename', how='outer').sort('filename')
infectio_filenames = infectio_mdata['filename']
infectio_mdata = infectio_mdata.drop('filename', axis=1).fillna(0)

# Clean cp
version = 'CellProfiler_v1.0'
dash = 'v1.0'
names = dict((n, n + '_' + dash) for n in norm_data['cp'][version].columns if (n != 'filename' and n != 'pathname'))
norm_data['cp'][version].rename(columns=names, inplace=True)
cp_mdata = norm_data['cp'][version].sort('filename')
cp_filenames = cp_mdata['filename']
cp_mdata = cp_mdata.drop(['filename', 'pathname'], axis=1)

            
# Normalize infectio
# norm_data = norm_metrics(data)
# for name in norm_data:
#     dash = name.replace('Infectio_', '')
#     norm_data[name] = norm_data[name].drop('pathname', axis=1)
#     names = dict((n, n + '_' + dash) for n in norm_data[name].columns if n != 'filename')
#     norm_data[name].rename(columns=names, inplace=True)

# hardcoded merge :)
# mdata = norm_data['Infectio_v0.1'].merge(norm_data['Infectio_v0.2']).merge(norm_data['Infectio_v0.3']).sort('filename')
# filenames = mdata['filename']
# mdata = mdata.drop('filename', axis=1)

# infectio_mdata
# cp_mdata
# Out:
#      line_counts_v1.0  comments_v1.0  cyclomatic_complexity_v1.0  \
# 0            0.049511       0.089674                    0.185714
# 1            0.021716       0.017210                    0.078571
# 4            0.001086       0.001812                    0.000000
# 5            0.001737       0.004529                    0.000000
# 6            0.001086       0.002717                    0.000000
# 7            0.000651       0.000906                    0.000000
# 8            0.000434       0.000000                    0.000000
# 9            0.000869       0.001812                    0.000000
# 10           0.000434       0.000000                    0.000000
# 11           0.000869       0.000906                    0.000000
# 12           0.000434       0.000000                    0.000000
# 13           0.001086       0.002717                    0.000000
# 14           0.000651       0.000906                    0.000000
# 15           0.001086       0.002717                    0.000000
# 16           0.001086       0.002717                    0.000000
# 17           0.000869       0.001812                    0.000000
# 18           0.000869       0.001812                    0.000000
# 19           0.000434       0.000000                    0.000000
# 20           0.000651       0.000906                    0.000000
# 21           0.000434       0.000000                    0.000000
# 22           0.001737       0.005435                    0.000000
# 23           0.000651       0.000906                    0.000000
# 24           0.001737       0.005435                    0.000000
# 25           0.003257       0.011775                    0.000000
# 26           0.000651       0.000906                    0.000000
# 27           0.000434       0.000000                    0.000000
# 28           0.000434       0.000000                    0.000000
# 29           0.000651       0.000906                    0.000000
# 30           0.000869       0.001812                    0.000000
# 31           0.000869       0.001812                    0.000000
# ..                ...            ...                         ...
# 728          0.022150       0.056159                    0.042857
# 729          0.079262       0.153080                    0.321429
# 730          0.059935       0.186594                    0.092857
# 731          0.052552       0.159420                    0.085714
# 732          0.039305       0.102355                    0.092857
# 733          0.108360       0.285326                    0.321429
# 734          0.024539       0.057065                    0.021429
# 735          0.102932       0.240942                    0.214286
# 736          0.080130       0.180254                    0.200000
# 737          0.080347       0.171196                    0.185714
# 738          0.056460       0.124094                    0.135714
# 739          0.137242       0.331522                    0.307143
# 740          0.063409       0.211051                    0.085714
# 741          0.039088       0.096920                    0.114286
# 742          0.013681       0.038949                    0.035714
# 743          0.034528       0.074275                    0.085714
# 744          0.100326       0.163949                    0.171429
# 745          0.071661       0.131341                    0.278571
# 746          0.038219       0.110507                    0.071429
# 747          0.051466       0.166667                    0.064286
# 748          0.031922       0.079710                    0.121429
# 749          0.016938       0.033514                    0.057143
# 750          0.133985       0.267210                    0.750000
# 751          0.029967       0.084239                    0.107143
# 752          0.090988       0.215580                    0.164286
# 753          0.040174       0.126812                    0.092857
# 754          0.029099       0.067935                    0.085714
# 755          0.048208       0.117754                    0.085714
# 756          0.085993       0.161232                    0.271429
# 757          0.140934       0.309783                    0.235714
#
#      help_metric_v1.0
# 0            0.333333
# 1            0.333333
# 4            1.000000
# 5            1.000000
# 6            1.000000
# 7            1.000000
# 8            1.000000
# 9            1.000000
# 10           1.000000
# 11           1.000000
# 12           1.000000
# 13           1.000000
# 14           1.000000
# 15           1.000000
# 16           1.000000
# 17           1.000000
# 18           1.000000
# 19           1.000000
# 20           1.000000
# 21           1.000000
# 22           1.000000
# 23           1.000000
# 24           1.000000
# 25           1.000000
# 26           1.000000
# 27           1.000000
# 28           1.000000
# 29           1.000000
# 30           1.000000
# 31           1.000000
# ..                ...
# 728          0.333333
# 729          0.333333
# 730          0.333333
# 731          0.000000
# 732          0.333333
# 733          0.000000
# 734          0.333333
# 735          0.333333
# 736          0.333333
# 737          0.000000
# 738          0.333333
# 739          0.333333
# 740          0.333333
# 741          0.333333
# 742          0.333333
# 743          0.333333
# 744          0.333333
# 745          0.333333
# 746          0.000000
# 747          0.333333
# 748          0.333333
# 749          0.333333
# 750          0.000000
# 751          0.333333
# 752          0.333333
# 753          0.333333
# 754          0.333333
# 755          0.333333
# 756          0.333333
# 757          0.333333
#
# [758 rows x 4 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


def plot_norm_metrics(norm_metrics, size, column_names, row_names):
    # Expect `norm_metrics` to contain all the min-max normalized metrics sorted by `filename`


    # Plot it out
    fig, ax = plt.subplots()
    heatmap = ax.pcolor(norm_metrics, cmap=plt.cm.Blues, alpha=0.8)

    ##################################################
    ## FORMAT ##
    ##################################################

    fig = plt.gcf()
    fig.set_size_inches(size[0], size[1], dpi=300)

    # turn off the frame
    ax.set_frame_on(False)

    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(norm_metrics.shape[0]) + 0.5, minor=False)
    ax.set_xticks(np.arange(norm_metrics.shape[1]) + 0.5, minor=False)

    # want a more natural, table-like display
    ax.invert_yaxis()
    ax.xaxis.tick_top()

    # Set the labels

    # 
    ax.set_xticklabels(column_names, minor=False) 
    #ax.set_yticklabels(norm_metrics.index, minor=False)
    ax.set_yticklabels(row_names, minor=False)

    # rotate the 
    plt.xticks(rotation=90)
    
    ax.grid(False)

    # Turn off all the ticks
    ax = plt.gca()

    for t in ax.xaxis.get_major_ticks(): 
        t.tick1On = False 
        t.tick2On = False 
    for t in ax.yaxis.get_major_ticks(): 
        t.tick1On = False 
        t.tick2On = False

# %%
plot_norm_metrics(infectio_mdata, size=(8,20), column_names=infectio_mdata.columns, row_names=infectio_filenames)

# %% [markdown]
# ## Computing avg

# %%
mknd = infectio_mdata.corr('kendall')
mknd
# Out:
#                             line_counts_v0.3  comments_v0.3  \
# line_counts_v0.3                    1.000000       0.791952
# comments_v0.3                       0.791952       1.000000
# cyclomatic_complexity_v0.3          0.645830       0.525103
# help_metric_v0.3                   -0.001986      -0.078262
# line_counts_v0.2                    0.716683       0.548775
# comments_v0.2                       0.583642       0.720999
# cyclomatic_complexity_v0.2          0.499443       0.389726
# help_metric_v0.2                   -0.075257      -0.168448
# line_counts_v0.1                    0.610688       0.437320
# comments_v0.1                       0.421696       0.593189
# cyclomatic_complexity_v0.1          0.426912       0.327119
# help_metric_v0.1                   -0.261847      -0.361443
#
#                             cyclomatic_complexity_v0.3  help_metric_v0.3  \
# line_counts_v0.3                              0.645830         -0.001986
# comments_v0.3                                 0.525103         -0.078262
# cyclomatic_complexity_v0.3                    1.000000          0.095350
# help_metric_v0.3                              0.095350          1.000000
# line_counts_v0.2                              0.550308         -0.028835
# comments_v0.2                                 0.475844         -0.116101
# cyclomatic_complexity_v0.2                    0.783010          0.045741
# help_metric_v0.2                              0.050544          0.786776
# line_counts_v0.1                              0.400189         -0.257376
# comments_v0.1                                 0.281071         -0.361332
# cyclomatic_complexity_v0.1                    0.766055         -0.097124
# help_metric_v0.1                             -0.120575          0.719489
#
#                             line_counts_v0.2  comments_v0.2  \
# line_counts_v0.3                    0.716683       0.583642
# comments_v0.3                       0.548775       0.720999
# cyclomatic_complexity_v0.3          0.550308       0.475844
# help_metric_v0.3                   -0.028835      -0.116101
# line_counts_v0.2                    1.000000       0.814766
# comments_v0.2                       0.814766       1.000000
# cyclomatic_complexity_v0.2          0.748270       0.642495
# help_metric_v0.2                    0.155287       0.072642
# line_counts_v0.1                    0.578610       0.464503
# comments_v0.1                       0.413949       0.585137
# cyclomatic_complexity_v0.1          0.449121       0.391578
# help_metric_v0.1                   -0.164536      -0.257092
#
#                             cyclomatic_complexity_v0.2  help_metric_v0.2  \
# line_counts_v0.3                              0.499443         -0.075257
# comments_v0.3                                 0.389726         -0.168448
# cyclomatic_complexity_v0.3                    0.783010          0.050544
# help_metric_v0.3                              0.045741          0.786776
# line_counts_v0.2                              0.748270          0.155287
# comments_v0.2                                 0.642495          0.072642
# cyclomatic_complexity_v0.2                    1.000000          0.232898
# help_metric_v0.2                              0.232898          1.000000
# line_counts_v0.1                              0.381075         -0.204057
# comments_v0.1                                 0.268852         -0.304294
# cyclomatic_complexity_v0.1                    0.685658         -0.060453
# help_metric_v0.1                             -0.084627          0.662428
#
#                             line_counts_v0.1  comments_v0.1  \
# line_counts_v0.3                    0.610688       0.421696
# comments_v0.3                       0.437320       0.593189
# cyclomatic_complexity_v0.3          0.400189       0.281071
# help_metric_v0.3                   -0.257376      -0.361332
# line_counts_v0.2                    0.578610       0.413949
# comments_v0.2                       0.464503       0.585137
# cyclomatic_complexity_v0.2          0.381075       0.268852
# help_metric_v0.2                   -0.204057      -0.304294
# line_counts_v0.1                    1.000000       0.773879
# comments_v0.1                       0.773879       1.000000
# cyclomatic_complexity_v0.1          0.579950       0.451905
# help_metric_v0.1                   -0.133625      -0.211848
#
#                             cyclomatic_complexity_v0.1  help_metric_v0.1
# line_counts_v0.3                              0.426912         -0.261847
# comments_v0.3                                 0.327119         -0.361443
# cyclomatic_complexity_v0.3                    0.766055         -0.120575
# help_metric_v0.3                             -0.097124          0.719489
# line_counts_v0.2                              0.449121         -0.164536
# comments_v0.2                                 0.391578         -0.257092
# cyclomatic_complexity_v0.2                    0.685658         -0.084627
# help_metric_v0.2                             -0.060453          0.662428
# line_counts_v0.1                              0.579950         -0.133625
# comments_v0.1                                 0.451905         -0.211848
# cyclomatic_complexity_v0.1                    1.000000         -0.016905
# help_metric_v0.1                             -0.016905          1.000000

# %%
plot_norm_metrics(mknd, size=(5,5), column_names=mknd.columns, row_names=mknd.index)

# %%
def get_complexity_score(metrics, versions=['0.1', '0.2', '0.3']):
    cscore = {}
    for version in versions:        
        # cscore[version] = metrics['line_counts_v%s' % version].mean() / metrics['comments_v%s' % version].mean() * metrics['cyclomatic_complexity_v%s' % version].mean()
        #cscore[version] = ((metrics['line_counts_v%s' % version] + (1 - metrics['comments_v%s' % version]) + metrics['cyclomatic_complexity_v%s' % version]) / 3).mean()
        cscore[version] = ((metrics['line_counts_v%s' % version] + metrics['comments_v%s' % version] + metrics['cyclomatic_complexity_v%s' % version]) / 3).mean()
    
    return cscore

def get_norm_filenumber(data, cscore, version_ptrn='Infectio_v%s'):
    filecounts = [data[version_ptrn % key].shape[0] for key in cscore]
    filenum = {}
    for key in cscore:
        filenum[key] = (float(data[version_ptrn % key].shape[0]) - min(filecounts)) / (max(filecounts) - min(filecounts))
    return filenum

def normalize_by_filenumber(data, cscore):
    filenum = get_norm_filenumber(data, cscore)
    ncscore = {}
    for key in cscore:
        ncscore[key] =  (filenum[key] + cscore[key])/2
    return ncscore

infectio_versions = ['0.1', '0.2', '0.3']
infectio_cscore = get_complexity_score(infectio_mdata)
infectio_filenum = get_norm_filenumber(data['infectio'], infectio_cscore)
infectio_ncscore = normalize_by_filenumber(data['infectio'], infectio_cscore)
print 'Infectio scoring:'
for version in infectio_versions:
    print '%s => version score: %s | avaraged by number of files: %s' % (version, infectio_cscore[version], infectio_ncscore[version])

#pd.DataFrame(, columns=['ncomplexity', 'nfilecount'])
# Out:
# Infectio scoring:
# 0.1 => version score: 0.0221509847209 | avaraged by number of files: 0.51107549236
# 0.2 => version score: 0.0190069174504 | avaraged by number of files: 0.0095034587252
# 0.3 => version score: 0.0207209847499 | avaraged by number of files: 0.299834176585

# %%
plot_norm_metrics(cp_mdata, size=(2,100), column_names=cp_mdata.columns, row_names=cp_filenames)

# %%
cp_versions = ['1.0']
# print cp_mdata
cp_cscore = get_complexity_score(cp_mdata, cp_versions)
# cp_filenum = get_norm_filenumber(data['cp'], cp_cscore)
# cp_ncscore = normalize_by_filenumber(data['cp'], cp_cscore)
print 'cp scoring:'
for version in cp_versions:
#     print 'version score: %s | avaraged by number of files: %s' % (cp_cscore[version], cp_ncscore[version])
    print '%s => version score: %s' % (version, cp_cscore[version])
# Out:
# cp scoring:
# version score: 0.0268104171623
